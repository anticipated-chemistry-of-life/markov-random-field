# %%
import pandas as pd


trace = pd.read_csv("acol_trace.txt", sep="\t")

# %%
trace
# Out:
#       gamma_1   gamma_2  molecules_mu_0_1  molecules_mu_0_2  molecules_mu_0_3  \
# 0     1719.89   2623.11               0.5               0.5               0.5
# 1     2291.16   3229.09               0.5               0.5               0.5
# 2     2332.52   3212.31               0.5               0.5               0.5
# 3     2280.97   3167.61               0.5               0.5               0.5
# 4     2312.57   3099.59               0.5               0.5               0.5
# ...       ...       ...               ...               ...               ...
# 9995  8115.66  44646.00               0.5               0.5               0.5
# 9996  8387.12  45009.90               0.5               0.5               0.5
# 9997  8984.07  45296.20               0.5               0.5               0.5
# 9998  9181.11  45402.30               0.5               0.5               0.5
# 9999  9189.79  45494.70               0.5               0.5               0.5
#
# ...

# %%
trace.species_mu_1_1.plot()
# Out:
# <Axes: >
