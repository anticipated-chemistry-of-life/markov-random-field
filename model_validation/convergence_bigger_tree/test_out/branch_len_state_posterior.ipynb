# %%
import pandas as pd

# %%
posterior = pd.read_csv("./acol_species_statePosteriors.txt", sep="\t", index_col=0)

# %%
posterior.T
# Out:
# name      species_branch_lengths_1  species_branch_lengths_2  \
# state_0                    0.00568                   0.00626
# state_1                    0.01122                   0.01272
# state_2                    0.01212                   0.01297
# state_3                    0.01227                   0.01290
# state_4                    0.01185                   0.01322
# ...                            ...                       ...
# state_95                   0.00744                   0.00594
# state_96                   0.00675                   0.00597
# state_97                   0.00649                   0.00588
# state_98                   0.00680                   0.00610
# state_99                   0.00346                   0.00321
#
# name      species_branch_lengths_3  species_branch_lengths_4  \
# state_0                    0.00568                   0.00841
# state_1                    0.01158                   0.01714
# ...

# %%
import seaborn as sns

sns.scatterplot(
    data=posterior.T, y="species_branch_lengths_1", x=range(len(posterior.T))
)
# Out:
# <Axes: ylabel='species_branch_lengths_1'>

# %%
posterior = pd.read_csv("./acol_molecules_statePosteriors.txt", sep="\t", index_col=0)

# %%
import seaborn as sns

sns.scatterplot(
    data=posterior.T, y="molecules_branch_lengths_1", x=range(len(posterior.T))
)
# Out:
# <Axes: ylabel='molecules_branch_lengths_1'>
