# %%
import pandas as pd


trace = pd.read_csv("acol_trace.txt", sep="\t")

which_mu = "species_mu_0_6"

# %%
print(trace[which_mu].mean())
print(trace[which_mu].var())
# Out:
# 19130.888543457186
# 91563512.22819425

# %%
trace
# Out:
#             gamma_1       gamma_2  molecules_mu_0_1  molecules_mu_0_2  \
# 0          0.001000      0.000000              0.12              0.12
# 1          0.139384      0.018162              0.12              0.12
# 2          0.534870      0.021875              0.12              0.12
# 3          0.218802      0.186848              0.12              0.12
# 4          0.153226      0.409548              0.12              0.12
# ...             ...           ...               ...               ...
# 10996  26833.700000  19790.100000              0.12              0.12
# 10997  27434.800000  20135.300000              0.12              0.12
# 10998  28164.000000  19963.700000              0.12              0.12
# 10999  28467.400000  19783.400000              0.12              0.12
# 11000  28797.900000  19560.700000              0.12              0.12
#
#        molecules_mu_0_3  molecules_mu_0_4  molecules_mu_0_5  molecules_mu_0_6  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=trace, y=which_mu, x=range(len(trace)), s=5)
plt.axhline(y=trace[which_mu][0], color="red")
