# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("./acol_simulated_joint_density.txt", sep="\t")

# %%
df
# Out:
#       joint_density
# 0          -168.613
# 1          -229.345
# 2          -183.208
# 3          -162.277
# 4          -178.841
# ...             ...
# 4995       -152.011
# 4996       -174.219
# 4997       -172.370
# 4998       -197.244
# 4999       -137.695
#
# [5000 rows x 1 columns]

# %%
sns.scatterplot(data=df, x=range(len(df)), y="joint_density", size=1)
# Out:
# <Axes: ylabel='joint_density'>
