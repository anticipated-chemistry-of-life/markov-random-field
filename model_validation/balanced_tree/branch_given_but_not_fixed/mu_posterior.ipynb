# %%
import pandas as pd


trace = pd.read_csv("acol_trace.txt", sep="\t")

# %%
trace
# Out:
#             gamma_1       gamma_2  molecules_mu_0_1  molecules_mu_0_2  \
# 0          0.001000      0.000000          0.500000          0.500000
# 1          0.007359      0.092022          0.500000          0.500000
# 2          0.013319      0.681847          0.024648          0.125996
# 3          0.038737      0.777203          0.019951          0.004203
# 4          0.159284      1.083120          0.016690          0.004203
# ...             ...           ...               ...               ...
# 10996  14408.500000  42285.600000          0.000649          0.000385
# 10997  14381.000000  42208.100000          0.000466          0.000339
# 10998  14301.800000  42507.700000          0.000483          0.000505
# 10999  14407.800000  42465.000000          0.000550          0.000651
# 11000  14627.500000  41977.000000          0.000566          0.000985
#
#        molecules_mu_0_3  molecules_mu_0_4  molecules_mu_0_5  molecules_mu_0_6  \
# ...

# %%
trace.molecules_mu_0_2.plot()
# Out:
# <Axes: >
