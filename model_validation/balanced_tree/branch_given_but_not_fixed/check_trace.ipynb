# %%
import pandas as pd

trace = pd.read_csv("./acol_trace.txt", sep="\t")

# %%
trace
# Out:
#             gamma_1       gamma_2  molecules_mu_0_1  molecules_mu_0_2  \
# 0          0.001000      0.000000               0.5               0.5
# 1          0.084448      0.038981               0.5               0.5
# 2          0.011973      0.353331               0.5               0.5
# 3          0.095100      0.084971               0.5               0.5
# 4          0.319009      0.417019               0.5               0.5
# ...             ...           ...               ...               ...
# 10996  35106.400000  10702.800000               0.5               0.5
# 10997  34734.700000  10943.900000               0.5               0.5
# 10998  34858.700000  10862.300000               0.5               0.5
# 10999  34253.400000  10606.300000               0.5               0.5
# 11000  34221.700000  11049.400000               0.5               0.5
#
#        molecules_mu_0_3  molecules_mu_0_4  molecules_mu_0_5  molecules_mu_0_6  \
# 0                   0.5               0.5               0.5               0.5
# 1                   0.5               0.5               0.5               0.5
# 2                   0.5               0.5               0.5               0.5
# 3                   0.5               0.5               0.5               0.5
# 4                   0.5               0.5               0.5               0.5
# ...                 ...               ...               ...               ...
# 10996               0.5               0.5               0.5               0.5
# 10997               0.5               0.5               0.5               0.5
# 10998               0.5               0.5               0.5               0.5
# 10999               0.5               0.5               0.5               0.5
# 11000               0.5               0.5               0.5               0.5
#
#        molecules_mu_0_7  molecules_mu_0_8  ...  species_mu_1_52  \
# 0                   0.5               0.5  ...              0.9
# 1                   0.5               0.5  ...              0.9
# 2                   0.5               0.5  ...              0.9
# 3                   0.5               0.5  ...              0.9
# 4                   0.5               0.5  ...              0.9
# ...                 ...               ...  ...              ...
# 10996               0.5               0.5  ...              0.9
# 10997               0.5               0.5  ...              0.9
# 10998               0.5               0.5  ...              0.9
# 10999               0.5               0.5  ...              0.9
# 11000               0.5               0.5  ...              0.9
#
#        species_mu_1_53  species_mu_1_54  species_mu_1_55  species_mu_1_56  \
# 0                  0.9              0.9              0.9              0.9
# 1                  0.9              0.9              0.9              0.9
# 2                  0.9              0.9              0.9              0.9
# 3                  0.9              0.9              0.9              0.9
# 4                  0.9              0.9              0.9              0.9
# ...                ...              ...              ...              ...
# 10996              0.9              0.9              0.9              0.9
# 10997              0.9              0.9              0.9              0.9
# 10998              0.9              0.9              0.9              0.9
# 10999              0.9              0.9              0.9              0.9
# 11000              0.9              0.9              0.9              0.9
#
#        species_mu_1_57  species_mu_1_58  species_mu_1_59  species_mu_1_60  \
# 0                  0.9              0.9              0.9              0.9
# 1                  0.9              0.9              0.9              0.9
# 2                  0.9              0.9              0.9              0.9
# 3                  0.9              0.9              0.9              0.9
# 4                  0.9              0.9              0.9              0.9
# ...                ...              ...              ...              ...
# 10996              0.9              0.9              0.9              0.9
# 10997              0.9              0.9              0.9              0.9
# 10998              0.9              0.9              0.9              0.9
# 10999              0.9              0.9              0.9              0.9
# 11000              0.9              0.9              0.9              0.9
#
#        species_mu_1_61
# 0                  0.9
# 1                  0.9
# 2                  0.9
# 3                  0.9
# 4                  0.9
# ...                ...
# 10996              0.9
# 10997              0.9
# 10998              0.9
# 10999              0.9
# 11000              0.9
#
# [11001 rows x 140 columns]

# %%
trace.plot(y="molecules_mu_0_6")
# Out:
# <Axes: >

# %%
trace.plot(y="species_mu_0_6")
# Out:
# <Axes: >

# %%
trace.plot(y="molecules_mu_1_6")
# Out:
# <Axes: >
