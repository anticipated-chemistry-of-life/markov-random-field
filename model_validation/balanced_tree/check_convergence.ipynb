# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("./acol_simulated_joint_density.txt", sep="\t")

# %%
df
# Out:
#      joint_density
# 0         -876.023
# 1        -1212.250
# 2        -1296.950
# 3        -1276.310
# 4        -1348.680
# ..             ...
# 995      -1301.510
# 996      -1269.440
# 997      -1226.300
# 998      -1215.160
# 999      -1319.160
#
# [1000 rows x 1 columns]

# %%
sns.scatterplot(data=df, x=range(len(df)), y="joint_density")
# Out:
# <Axes: ylabel='joint_density'>
