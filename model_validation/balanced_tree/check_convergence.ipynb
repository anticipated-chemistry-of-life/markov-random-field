# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("./acol_simulated_joint_density.txt", sep="\t")

# %%
sns.scatterplot(data=df, x=range(len(df)), y="prob_0")
# Out:
# <Axes: ylabel='prob_0'>
