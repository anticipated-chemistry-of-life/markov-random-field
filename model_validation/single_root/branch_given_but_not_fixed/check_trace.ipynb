# %%
import pandas as pd

trace = pd.read_csv("./acol_trace.txt", sep="\t")

# %%
trace
# Out:
#             gamma_1       gamma_2  molecules_mu_0_1  molecules_mu_0_2  \
# 0          0.001000      0.000000          0.500000          0.500000
# 1          0.050597      0.171175          0.500000          0.437282
# 2          0.387657      0.101489          0.226567          0.340830
# 3          0.237882      0.545353          0.028265          0.042284
# 4          0.284730      0.326946          0.016851          0.008254
# ...             ...           ...               ...               ...
# 10996  10051.700000  17818.000000          0.000930          0.000181
# 10997   9894.840000  17586.000000          0.003699          0.000282
# 10998  10051.800000  18186.500000          0.002430          0.000282
# 10999  10188.300000  17843.100000          0.001082          0.000189
# 11000   9922.090000  17816.400000          0.001159          0.000274
#
#        molecules_mu_0_3  molecules_mu_0_4  molecules_mu_0_5  molecules_mu_0_6  \
# ...

# %%
trace.plot(y="molecules_mu_0_6")
# Out:
# <Axes: >

# %%
trace.plot(y="species_mu_0_6")
# Out:
# <Axes: >

# %%
trace.plot(y="molecules_mu_1_6")
# Out:
# <Axes: >
