# %%
import pandas as pd

# %%
choice = "species"
file = f"./acol_{choice}_statePosteriors.txt"

# %%
posterior = pd.read_csv(file, sep="\t", index_col=0)

# %%
posterior.T
# Out:
# name      species_branch_lengths_1  species_branch_lengths_2  \
# state_0                          0                         0
# state_1                          0                         0
# state_2                          1                         0
# state_3                          0                         1
# state_4                          0                         0
# ...                            ...                       ...
# state_95                         0                         0
# state_96                         0                         0
# state_97                         0                         0
# state_98                         0                         0
# state_99                         0                         0
#
# name      species_branch_lengths_3  species_branch_lengths_4  \
# state_0                          0                         0
# state_1                          0                         0
# state_2                          0                         0
# state_3                          0                         0
# state_4                          0                         0
# ...                            ...                       ...
# state_95                         0                         0
# state_96                         0                         0
# state_97                         0                         0
# state_98                         0                         0
# state_99                         0                         0
#
# name      species_branch_lengths_5  species_branch_lengths_6  \
# state_0                          0                         0
# state_1                          0                         0
# state_2                          0                         0
# state_3                          0                         0
# state_4                          0                         0
# ...                            ...                       ...
# state_95                         0                         0
# state_96                         0                         0
# state_97                         0                         0
# state_98                         0                         0
# state_99                         0                         0
#
# name      species_branch_lengths_7  species_branch_lengths_8  \
# state_0                          0                         0
# state_1                          0                         0
# state_2                          0                         0
# state_3                          0                         0
# state_4                          0                         0
# ...                            ...                       ...
# state_95                         0                         0
# state_96                         0                         0
# state_97                         0                         0
# state_98                         0                         0
# state_99                         0                         0
#
# name      species_branch_lengths_9  species_branch_lengths_10  \
# state_0                          0                          0
# state_1                          0                          0
# state_2                          0                          0
# state_3                          0                          0
# state_4                          0                          0
# ...                            ...                        ...
# state_95                         0                          0
# state_96                         0                          0
# state_97                         0                          0
# state_98                         0                          0
# state_99                         0                          0
#
# name      species_branch_lengths_11  species_branch_lengths_12
# state_0                           0                          0
# state_1                           0                          0
# state_2                           0                          0
# state_3                           0                          0
# state_4                           0                          0
# ...                             ...                        ...
# state_95                          0                          0
# state_96                          0                          0
# state_97                          0                          0
# state_98                          0                          0
# state_99                          0                          0
#
# [100 rows x 12 columns]

# %%
which_branch_len = f"{choice}_branch_lengths_5"

# %%
true_branch_length = pd.read_csv(f"../acol_{choice}_simulated.txt", sep="\t")

# %%
true_branch_length
# Out:
#                          name  value
# 0    species_branch_lengths_1      2
# 1    species_branch_lengths_2      3
# 2    species_branch_lengths_3      5
# 3    species_branch_lengths_4      6
# 4    species_branch_lengths_5      8
# 5    species_branch_lengths_6     10
# 6    species_branch_lengths_7     11
# 7    species_branch_lengths_8     13
# 8    species_branch_lengths_9     14
# 9   species_branch_lengths_10     16
# 10  species_branch_lengths_11     17
# 11  species_branch_lengths_12     19

# %%
true_val = true_branch_length[true_branch_length.name == which_branch_len][
    "value"
].to_numpy()

# %%
true_val
# Out:
# array([], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    data=posterior.T, y=which_branch_len, x=range(len(posterior.T))
).set_title(which_branch_len)
plt.axvline(x=true_val, color="red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 4 sns.scatterplot(
#       5     data=posterior.T, y=which_branch_len, x=range(len(posterior.T))
#       6 ).set_title(which_branch_len)
#       7 plt.axvline(x=true_val, color="red")
#
# File ~/work/random-markov-field/metabolite_inference/model_validation/single_root/.venv/lib/python3.13/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/work/random-markov-field/metabolite_inference/model_validation/single_root/.venv/lib/python3.13/site-packages/seaborn/relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File ~/work/random-markov-field/metabolite_inference/model_validation/single_root/.venv/lib/python3.13/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/work/random-markov-field/metabolite_inference/model_validation/single_root/.venv/lib/python3.13/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/work/random-markov-field/metabolite_inference/model_validation/single_root/.venv/lib/python3.13/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/work/random-markov-field/metabolite_inference/model_validation/single_root/.venv/lib/python3.13/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `species_branch_lengths_27` for `y`. An entry with this name does not appear in `data`.
